# %% [markdown]
# <a href="https://colab.research.google.com/github/TARUN965/ML_with_flask/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import preprocessing

# %%
file_name ="/content/drive/MyDrive/iris.csv"

# %%
import pandas as pd
iris = pd.read_csv(file_name)

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
iris.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
label_encoder = preprocessing.LabelEncoder()
iris['Species'] = label_encoder.fit_transform(iris['Species'])
iris['Species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
iris = iris.rename(columns={"Species":"Flowers_types"})

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#      Flowers_types
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
label_encoder = preprocessing.LabelEncoder()
iris['Flowers_types'] = label_encoder.fit_transform(iris['Flowers_types'])
iris['Flowers_types']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
x=iris.iloc[:,0:4]
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
y=iris["Flowers_types"]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
colnames = list(iris.columns)
colnames
# Out:
# ['Unnamed: 0',
#  'Sepal.Length',
#  'Sepal.Width',
#  'Petal.Length',
#  'Petal.Width',
#  'Flowers_types']

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#      Flowers_types
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...
